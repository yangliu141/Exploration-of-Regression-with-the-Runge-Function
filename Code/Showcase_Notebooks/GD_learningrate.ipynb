# %% [markdown]
# # Bias-variance tradeoff
#
# This notebook runs gradient descent on a specified function for different learning rates and different polynomial degrees. The final MSE and R2 are printed to the console.
#
# The data from this notebook is used in Table 3 of the article.

# %%
import sys
import os
# Add the project root to sys.path
sys.path.append(os.path.abspath('..'))

import numpy as np
from sklearn.preprocessing import normalize
from Functions.optimizers import Optimizers
from Functions.gradients import Gradients
from Functions.gradientdescent_lib import *
from Functions.runExperiments import RunAllExperiments
from Functions.PLOT import plot
# Out:
# c:\Users\maxfo\Python\Lib\site-packages\sklearn\utils\_param_validation.py:11: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.3)
#   from scipy.sparse import csr_matrix, issparse

# %%
np.random.seed(1)

n_points = 100

x_train, x_test, y_train, y_test = generateData(n_points, noise = 0.1)
x_train = x_train.flatten(); x_test = x_test.flatten()

# %%
n_degrees = [2, 4, 6, 12, 14, 16, 18]

lambd = 0.001

learningrates = [0.01, 0.05, 0.1, 0.5]

grad_OLS = Gradients.OLS()
grad_Ridge = Gradients.Ridge(lambd)

GRADIENTS = [grad_OLS, grad_Ridge]


for n_degree in n_degrees:
    for n in range(3):
        print('--------------------------------------------------------------------------------')
    print(f'Results for degree {n_degree}')
    noIntercept = False
    X_train = featureMat(x_train, n_degree, noIntercept=noIntercept)
    X_test = featureMat(x_test, n_degree, noIntercept=noIntercept)

    

    #R2 analytical OLS-------------------------------------------------------------------
    theta_a_OLS = theta_analytic_OLS(X_train, y_train)
    y_pred = X_test @ theta_a_OLS

    R2_a_OLS = R2(y_test, y_pred)
    print(f'Analytical OLS:   {R2_a_OLS}')

    #R2 analytical Ridge-----------------------------------------------------------------
    theta_a_Ridge = theta_analytic_Ridge(X_train, y_train, lambd)
    y_pred = X_test @ theta_a_Ridge

    R2_a_Ridge = R2(y_test, y_pred)
    print(f'Analytical Ridge: {R2_a_Ridge}')
    


    for learningrate in learningrates:
        optimizer = Optimizers.Simple(learningrate)
        print(' ----------------------------------------------------------')
        print(f'Learning rate = {learningrate}')
        print('-------------------------------')

        for gradient in GRADIENTS:
            model = GradientDescent(n_degree, logging = True)
            model.setOptimizer(optimizer)
            model.setGradient(gradient)

            model.train(X_train, y_train, X_test, y_test)
            y_pred = model.predict(X_test)

            R2_gd = R2(y_test, y_pred)
            print(f'R2 with {gradient} = {R2_gd}')
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Results for degree 2
# Analytical OLS:   0.4321608641771384
# Analytical Ridge: 0.43225059283071576
#  ----------------------------------------------------------
# Learning rate = 0.01
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 2 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.302 and was achived after 99 epochs.                The final MSE was 0.302.
# R2 with OLS = -2.004649244601465
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 2 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.590 and was achived after 99 epochs.                The final MSE was 0.590.
# R2 with Ridge = -4.866400827056635
#  ----------------------------------------------------------
# Learning rate = 0.05
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 2 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.070 and was achived after 99 epochs.                The final MSE was 0.070.
# R2 with OLS = 0.3002405373482263
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 2 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.087 and was achived after 99 epochs.                The final MSE was 0.087.
# R2 with Ridge = 0.1383362011878807
#  ----------------------------------------------------------
# Learning rate = 0.1
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 2 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.061 and was achived after 99 epochs.                The final MSE was 0.061.
# R2 with OLS = 0.3971294425249349
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 2 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.053 and was achived after 99 epochs.                The final MSE was 0.053.
# R2 with Ridge = 0.47257005870493807
#  ----------------------------------------------------------
# Learning rate = 0.5
# -------------------------------
# Training complete!
# Trained for 30 epoch with learning rate 0.5,                the model used 2 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.000 and was achived after 31 epochs.                The final MSE was 0.000.
# R2 with OLS = 0.4869762142148274
# Training complete!
# Trained for 33 epoch with learning rate 0.5,                the model used 2 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.000 and was achived after 34 epochs.                The final MSE was 0.000.
# R2 with Ridge = 0.48660937238607227
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Results for degree 4
# Analytical OLS:   0.7335037730807814
# Analytical Ridge: 0.7335688182942789
#  ----------------------------------------------------------
# Learning rate = 0.01
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 4 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.755 and was achived after 99 epochs.                The final MSE was 0.755.
# R2 with OLS = -6.50507450437598
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 4 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.416 and was achived after 99 epochs.                The final MSE was 0.416.
# R2 with Ridge = -3.1413422756406266
#  ----------------------------------------------------------
# Learning rate = 0.05
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 4 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.089 and was achived after 99 epochs.                The final MSE was 0.089.
# R2 with OLS = 0.11936391491338283
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 4 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.082 and was achived after 99 epochs.                The final MSE was 0.082.
# R2 with Ridge = 0.18072052478840395
#  ----------------------------------------------------------
# Learning rate = 0.1
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 4 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.045 and was achived after 99 epochs.                The final MSE was 0.045.
# R2 with OLS = 0.5533585394236247
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 4 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.053 and was achived after 99 epochs.                The final MSE was 0.053.
# R2 with Ridge = 0.47348849532904813
#  ----------------------------------------------------------
# Learning rate = 0.5
# -------------------------------
# Training complete!
# Trained for 33 epoch with learning rate 0.5,                the model used 4 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.000 and was achived after 34 epochs.                The final MSE was 0.000.
# R2 with OLS = 0.5311764965235071
# Training complete!
# Trained for 26 epoch with learning rate 0.5,                the model used 4 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.000 and was achived after 27 epochs.                The final MSE was 0.000.
# R2 with Ridge = 0.4889164258213523
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Results for degree 6
# Analytical OLS:   0.8330239588159842
# Analytical Ridge: 0.8370335262252802
#  ----------------------------------------------------------
# Learning rate = 0.01
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 6 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.880 and was achived after 99 epochs.                The final MSE was 0.880.
# R2 with OLS = -7.750842457718528
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 6 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 1.057 and was achived after 99 epochs.                The final MSE was 1.057.
# R2 with Ridge = -9.513001256290723
#  ----------------------------------------------------------
# Learning rate = 0.05
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 6 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.119 and was achived after 99 epochs.                The final MSE was 0.119.
# R2 with OLS = -0.1848854500754482
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 6 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.079 and was achived after 99 epochs.                The final MSE was 0.079.
# R2 with Ridge = 0.21122116223774257
#  ----------------------------------------------------------
# Learning rate = 0.1
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 6 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.060 and was achived after 99 epochs.                The final MSE was 0.060.
# R2 with OLS = 0.40327139031487713
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 6 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.053 and was achived after 99 epochs.                The final MSE was 0.053.
# R2 with Ridge = 0.4764492983029607
#  ----------------------------------------------------------
# Learning rate = 0.5
# -------------------------------
# Training complete!
# Trained for 23 epoch with learning rate 0.5,                the model used 6 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.000 and was achived after 24 epochs.                The final MSE was 0.000.
# R2 with OLS = 0.4882867590412697
# Training complete!
# Trained for 25 epoch with learning rate 0.5,                the model used 6 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.000 and was achived after 26 epochs.                The final MSE was 0.000.
# R2 with Ridge = 0.3464317694794623
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Results for degree 12
# Analytical OLS:   0.763635411835975
# Analytical Ridge: 0.860376499134027
#  ----------------------------------------------------------
# Learning rate = 0.01
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 12 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 1.450 and was achived after 99 epochs.                The final MSE was 1.450.
# R2 with OLS = -13.421903397793645
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 12 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 2.947 and was achived after 99 epochs.                The final MSE was 2.947.
# R2 with Ridge = -28.305677277626003
#  ----------------------------------------------------------
# Learning rate = 0.05
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 12 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.153 and was achived after 99 epochs.                The final MSE was 0.153.
# R2 with OLS = -0.5198714120216918
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 12 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.072 and was achived after 99 epochs.                The final MSE was 0.072.
# R2 with Ridge = 0.2835417317953066
#  ----------------------------------------------------------
# Learning rate = 0.1
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 12 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.050 and was achived after 99 epochs.                The final MSE was 0.050.
# R2 with OLS = 0.5045858899267307
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 12 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.070 and was achived after 99 epochs.                The final MSE was 0.070.
# R2 with Ridge = 0.30223657602907517
#  ----------------------------------------------------------
# Learning rate = 0.5
# -------------------------------
# Training complete!
# Trained for 32 epoch with learning rate 0.5,                the model used 12 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.000 and was achived after 33 epochs.                The final MSE was 0.000.
# R2 with OLS = 0.5003325944475403
# Training complete!
# Trained for 21 epoch with learning rate 0.5,                the model used 12 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.000 and was achived after 22 epochs.                The final MSE was 0.000.
# R2 with Ridge = 0.4172860449624627
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Results for degree 14
# Analytical OLS:   0.8486269072979272
# Analytical Ridge: 0.8542965001885559
#  ----------------------------------------------------------
# Learning rate = 0.01
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 14 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 2.259 and was achived after 99 epochs.                The final MSE was 2.259.
# R2 with OLS = -21.461880607670633
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 14 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 3.937 and was achived after 99 epochs.                The final MSE was 3.937.
# R2 with Ridge = -38.151631049501574
#  ----------------------------------------------------------
# Learning rate = 0.05
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 14 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.172 and was achived after 99 epochs.                The final MSE was 0.172.
# R2 with OLS = -0.7102457576158774
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 14 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.104 and was achived after 99 epochs.                The final MSE was 0.104.
# R2 with Ridge = -0.03561659178187693
#  ----------------------------------------------------------
# Learning rate = 0.1
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 14 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.047 and was achived after 99 epochs.                The final MSE was 0.047.
# R2 with OLS = 0.5334807088832558
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 14 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.049 and was achived after 99 epochs.                The final MSE was 0.049.
# R2 with Ridge = 0.5168519658996036
#  ----------------------------------------------------------
# Learning rate = 0.5
# -------------------------------
# Training complete!
# Trained for 26 epoch with learning rate 0.5,                the model used 14 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.000 and was achived after 27 epochs.                The final MSE was 0.000.
# R2 with OLS = 0.5049542170472069
# Training complete!
# Trained for 27 epoch with learning rate 0.5,                the model used 14 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.000 and was achived after 28 epochs.                The final MSE was 0.000.
# R2 with Ridge = 0.48896781279281176
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Results for degree 16
# Analytical OLS:   -1.9065368925255752
# Analytical Ridge: 0.8434616380218822
#  ----------------------------------------------------------
# Learning rate = 0.01
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 16 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 1.975 and was achived after 99 epochs.                The final MSE was 1.975.
# R2 with OLS = -18.64228219681174
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 16 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 3.371 and was achived after 99 epochs.                The final MSE was 3.371.
# R2 with Ridge = -32.520240822916186
#  ----------------------------------------------------------
# Learning rate = 0.05
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 16 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.122 and was achived after 99 epochs.                The final MSE was 0.122.
# R2 with OLS = -0.21502868506866468
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 16 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.225 and was achived after 99 epochs.                The final MSE was 0.225.
# R2 with Ridge = -1.2326770380135619
#  ----------------------------------------------------------
# Learning rate = 0.1
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 16 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.078 and was achived after 99 epochs.                The final MSE was 0.078.
# R2 with OLS = 0.22123112746503704
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 16 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.043 and was achived after 99 epochs.                The final MSE was 0.043.
# R2 with Ridge = 0.5772019807483566
#  ----------------------------------------------------------
# Learning rate = 0.5
# -------------------------------
# Training complete!
# Trained for 34 epoch with learning rate 0.5,                the model used 16 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.000 and was achived after 35 epochs.                The final MSE was 0.000.
# R2 with OLS = 0.46484452234557316
# Training complete!
# Trained for 38 epoch with learning rate 0.5,                the model used 16 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.000 and was achived after 39 epochs.                The final MSE was 0.000.
# R2 with Ridge = 0.5177940690001259
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Results for degree 18
# Analytical OLS:   -3.180428218517852
# Analytical Ridge: 0.831440440164833
#  ----------------------------------------------------------
# Learning rate = 0.01
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 18 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 2.802 and was achived after 99 epochs.                The final MSE was 2.802.
# R2 with OLS = -26.863468746212156
# Training complete!
# Trained for 99 epoch with learning rate 0.01,                the model used 18 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 3.533 and was achived after 99 epochs.                The final MSE was 3.533.
# R2 with Ridge = -34.135297334999045
#  ----------------------------------------------------------
# Learning rate = 0.05
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 18 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.234 and was achived after 99 epochs.                The final MSE was 0.234.
# R2 with OLS = -1.3282173025730502
# Training complete!
# Trained for 99 epoch with learning rate 0.05,                the model used 18 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.283 and was achived after 99 epochs.                The final MSE was 0.283.
# R2 with Ridge = -1.8140187440158075
#  ----------------------------------------------------------
# Learning rate = 0.1
# -------------------------------
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 18 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.061 and was achived after 99 epochs.                The final MSE was 0.061.
# R2 with OLS = 0.39062839422603945
# Training complete!
# Trained for 99 epoch with learning rate 0.1,                the model used 18 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.054 and was achived after 99 epochs.                The final MSE was 0.054.
# R2 with Ridge = 0.4628138625786963
#  ----------------------------------------------------------
# Learning rate = 0.5
# -------------------------------
# Training complete!
# Trained for 30 epoch with learning rate 0.5,                the model used 18 features,                optimizer No optimizer and gradient OLS.
#                 The best MSE was 0.000 and was achived after 31 epochs.                The final MSE was 0.000.
# R2 with OLS = 0.463266715733315
# Training complete!
# Trained for 30 epoch with learning rate 0.5,                the model used 18 features,                optimizer No optimizer and gradient Ridge.
#                 The best MSE was 0.000 and was achived after 31 epochs.                The final MSE was 0.000.
# R2 with Ridge = 0.4253152346624225
